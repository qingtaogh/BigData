# %%
# !pip install --ignore-install -q pyspark
# Install findspark library
# !pip install --ignore-install -q findspark
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 20.5 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done

# %%
# Import findspark and set the SPARK_HOME and JAVA_HOME paths
import findspark
findspark.init()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from pyspark.sql import SparkSession
# Start the SparkSession
spark = SparkSession.builder.appName("Basics").getOrCreate()
# Read people.json file
df = spark.read.json('/content/drive/MyDrive/people.json')
# showing data
df.show()
# print schema
df.printSchema()
df.columns
df.describe()
# Retrieve data
df['age']
df.select('age').show()
# Returns list of Row objects
df.head(2)
# Return multiple columns
df.select(['age','name']).show()

# create new column
# Adding a new column with a simple copy
df.withColumn('newage',df['age']).show()
df.withColumnRenamed('name','given_name').show()
df.withColumn('doubleage',df['age']*2).show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+
#
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)
#
# +----+
# | age|
# +----+
# |NULL|
# |  30|
# |  19|
# +----+
#
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+
#
# +----+-------+------+
# | age|   name|newage|
# +----+-------+------+
# |NULL|Michael|  NULL|
# |  30|   Andy|    30|
# |  19| Justin|    19|
# +----+-------+------+
#
# +----+----------+
# | age|given_name|
# +----+----------+
# |NULL|   Michael|
# |  30|      Andy|
# |  19|    Justin|
# +----+----------+
#
# +----+-------+---------+
# | age|   name|doubleage|
# +----+-------+---------+
# |NULL|Michael|     NULL|
# |  30|   Andy|       60|
# |  19| Justin|       38|
# +----+-------+---------+
